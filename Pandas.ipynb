# %% [markdown]
# <a href="https://colab.research.google.com/github/Lakshmiec/fast-api-tutorial-series/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas is for data manipulation & analysis in Python.
#
# Key objects:
#
# Series → 1D labeled array
#
# DataFrame → 2D labeled table

# %%
import pandas as pd

# Create DataFrame
data = {'Name': ['Alice', 'Bob', 'Charlie'],
        'Age': [25, 30, 35]}
df = pd.DataFrame(data)

# View first rows
print(df.head())

# Select column
print(df['Name'])        # Series
print(df[['Name', 'Age']]) # DataFrame

# Filter rows
print(df[df['Age'] > 28])

# Add new column
df['Salary'] = [50000, 60000, 70000]

# Group by & aggregate
print(df.groupby('Age')['Salary'].mean())
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: object
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
#       Name  Age
# 1      Bob   30
# 2  Charlie   35
# Age
# 25    50000.0
# 30    60000.0
# 35    70000.0
# Name: Salary, dtype: float64

# %%
df.head(1)
# Out:
#     Name  Age  Salary
# 0  Alice   25   50000

# %%
df.tail(1)
# Out:
#       Name  Age  Salary
# 2  Charlie   35   70000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   Salary  3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 204.0+ bytes

# %%
df.describe()
# Out:
#         Age   Salary
# count   3.0      3.0
# mean   30.0  60000.0
# std     5.0  10000.0
# min    25.0  50000.0
# 25%    27.5  55000.0
# 50%    30.0  60000.0
# 75%    32.5  65000.0
# max    35.0  70000.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(df['Age'] > 28)
# Out:
# 0    False
# 1     True
# 2     True
# Name: Age, dtype: bool

# %%
# Filter rows
print(df[df['Age'] > 28])
# Out:
#       Name  Age  Salary
# 1      Bob   30   60000
# 2  Charlie   35   70000

# %%
print(df['Name'])
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: object

# %%
print(df[['Name']])
# Out:
#       Name
# 0    Alice
# 1      Bob
# 2  Charlie

# %%
df[['Name','Age']]
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %% [markdown]
# ## To find teh version

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.2.2

# %% [markdown]
# ## What is Pandas Series
#
# A Pandas Series is like a column in a table.
#
# It is a one-dimensional array holding data of any type.

# %%
# Create a simple Pandas Series from a list:

import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a)

print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %% [markdown]
# ## Labels
#
# If nothing else is specified, the values are labeled with their index number. First value has index 0, second value has index 1 etc.
#
# This label can be used to access a specified value.

# %%
print(myvar[0])
# Out:
# 1

# %% [markdown]
# #### Create Labels
# With the index argument, you can name your own labels.

# %%
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a, index = ["x", "y", "z"])

print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %% [markdown]
# #### Key/Value Objects as Series
#
# You can also use a key/value object, like a dictionary, when creating a Series.

# %% [markdown]
# Note: The keys of the dictionary become the labels.

# %%
# Example
# Create a simple Pandas Series from a dictionary:

import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %% [markdown]
# To select only some of the items in the dictionary, use the index argument and specify only the items you want to include in the Series

# %%
# Create a Series using only data from "day1" and "day2":

import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories, index = ["day1", "day2"])

print(myvar)
# Out:
# day1    420
# day2    380
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# # DataFrames
#
# Data sets in Pandas are usually multi-dimensional tables, called DataFrames.
#
# A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.
#
# -- Series is like a column, a DataFrame is the whole table.

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

myvar = pd.DataFrame(data)

print(myvar)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %% [markdown]
# ### Locate Row - `loc`
#
# Pandas use the loc attribute to return one or more specified row(s)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Note: When slicing, both from and to are included in the result.**

# %%
import pandas as pd

data = [[50, True], [40, False], [30, False]]
label_rows = ["Sally", "Mary", "John"]
label_cols = ["age", "qualified"]

df = pd.DataFrame(data, label_rows, label_cols)
print(df.loc["Mary", "age"])
# Out:
# 40

# %%
df.loc['sally':'Mary']
# Out:
#        age  qualified
# Sally   50       True
# Mary    40      False

# %% [markdown]
# Return Value
# Depends on the input:
#
# Single labels for both row and column ["Sally", "age"] returns the content of that cell.
#
# Single label for one row ["Sally"] returns a Pandas Series.
#
# A list of labels [["Sally", "Mary"]] returns a Pandas DataFrame.

# %%
#refer to the row index:
print(df.loc[1])
# Out:
# Name        Bob
# Age          30
# Salary    60000
# Name: 1, dtype: object

# %% [markdown]
# Note: This example returns a Pandas Series.

# %%
#use a list of indexes:
print(df.loc[[0, 1]])
# Out:
#     Name  Age  Salary
# 0  Alice   25   50000
# 1    Bob   30   60000

# %%
#refer to the row index:
#
print(df.loc[[1]])
# Out:
#   Name  Age  Salary
# 1  Bob   30   60000

# %% [markdown]
# Note: When using [], the result is a Pandas DataFrame.

# %% [markdown]
# This example returns a dataframe

# %%
# Out:
# Name        Bob
# Age          30
# Salary    60000
# Name: 1, dtype: object

# %% [markdown]
# ### Difference between `loc` and `iloc`
#
# In Pandas, `loc` and `iloc` are used to access groups of rows and columns from a DataFrame. The key difference lies in how they use indexing:
#
# *   **`loc`**: This is primarily label-based indexing. When using `loc`, you refer to rows and columns by their labels (index names and column names).
# *   **`iloc`**: This is primarily integer-based indexing. When using `iloc`, you refer to rows and columns by their integer position (starting from 0).
#
# Here's a simple example:
#
# Let's say you have a DataFrame `df` with index labels 'a', 'b', 'c' and columns 'A', 'B'.
#
# - To access the row with label 'b' using `loc`: `df.loc['b']`
# - To access the row at the second position (index 1) using `iloc`: `df.iloc[1]`
#
# - To access the column with label 'A' using `loc`: `df.loc[:, 'A']`
# - To access the first column (index 0) using `iloc`: `df.iloc[:, 0]`
#
# - To access the element at row 'b' and column 'A' using `loc`: `df.loc['b', 'A']`
# - To access the element at the second row (index 1) and first column (index 0) using `iloc`: `df.iloc[1, 0]`

# %%
g

# %%
# Example using loc with the existing df DataFrame

# Accessing a row by label (index)
print("Accessing row with index 1 using loc:")
print(df.loc[1])

# Accessing multiple rows by labels (indices)
print("\nAccessing rows with indices 0 and 2 using loc:")
print(df.loc[[0, 2]])

# Accessing a specific value using row and column labels
print("\nAccessing value at row with index 1 and column 'Name' using loc:")
print(df.loc[1, 'Name'])

# Accessing multiple columns for specific rows using loc
print("\nAccessing 'Name' and 'Salary' columns for rows with indices 0 and 1 using loc:")
print(df.loc[[0, 1], ['Name', 'Salary']])

# %%
# Example using iloc with the existing df DataFrame

# Accessing a row by integer position
print("Accessing row at integer position 1 using iloc:")
print(df.iloc[1])

# Accessing multiple rows by integer positions
print("\nAccessing rows at integer positions 0 and 2 using iloc:")
print(df.iloc[[0, 2]])

# Accessing a specific value using row and column integer positions
print("\nAccessing value at integer position 1 (row) and 0 (column) using iloc:")
print(df.iloc[1, 0])

# Accessing multiple columns for specific rows using iloc
print("\nAccessing columns at integer positions 0 and 2 for rows at integer positions 0 and 1 using iloc:")
print(df.iloc[[0, 1], [0, 2]])

# %%
print("\nAccessing rows at integer positions 0 and 2 using iloc:")
print(df.iloc[0, 2])
# Out:
# Accessing rows at integer positions 0 and 2 using iloc:
# 50000

# %% [markdown]
# ### `iloc` attribute

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Note: When slicing, the to index is excluded from the result.**

# %% [markdown]
# Return Value
# Depends on the input:
#
# Single indexes for both row and column [1, 0] returns the content of that cell.
#
# Single index for one row [1] returns a Pandas Series.
#
# A list of indexes [[0, 2]] returns a Pandas DataFrame.

# %% [markdown]
# ---

# %% [markdown]
# # Read CSV Files
# A simple way to store big data sets is to use CSV files (comma separated files).
#
# CSV files contains plain text and is a well know format that can be read by everyone including Pandas.
#
# In our examples we will be using a CSV file called 'data.csv'.

# %% [markdown]
# Tip: use `to_string()` to print the entire DataFrame

# %% [markdown]
# If you have a large DataFrame with many rows, Pandas will only return the first 5 rows, and the last 5 rows:

# %%
import pandas as pd

df = pd.read_csv('/data.csv')

print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## Read JSON
#
# Big data sets are often stored, or extracted as JSON.
#
# JSON is plain text, but has the format of an object, and is well known in the world of programming, including Pandas.
#
# In our examples we will be using a JSON file called 'data.json'.
#
# Open data.json.

# %%
import pandas as pd

df = pd.read_json('data.json')

print(df.to_string())

# %% [markdown]
# #### JSON = Python Dictionary
#
# JSON objects have the same format as Python dictionaries.

# %%
# Load a Python Dictionary into a DataFrame:

import pandas as pd

data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %% [markdown]
# ---

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Pandas - Cleaning Empty Cells

# %% [markdown]
# ### Remove Rows ---

# %% [markdown]
# Empty cells can potentially give you a wrong result when you analyze data.
#
# Remove Rows ---
#
# One way to deal with empty cells is to remove rows that contain empty cells.
#
# This is usually OK, since data sets can be very big, and removing a few rows will not have a big impact on the result.

# %% [markdown]
# ### `dropna`

# %%
# Return a new Data Frame with no empty cells:
import pandas as pd

df = pd.read_csv('data.csv')

new_df = df.dropna()

print(new_df.to_string())

# %% [markdown]
# Rows with empty cells are removed

# %% [markdown]
# Note: By default, the dropna() method returns a new DataFrame, and will not change the original.

# %% [markdown]
# If you want to change the original DataFrame, use the inplace = True argument:

# %%
# Remove all rows with NULL values:

import pandas as pd

df = pd.read_csv('data.csv')

df.dropna(inplace = True)

print(df.to_string())

# %% [markdown]
# `Note:` Now, the dropna(inplace = True) will NOT return a new DataFrame, but it will remove all rows containing NULL values from the original DataFrame.

# %% [markdown]
# ### Replace Empty Values

# %% [markdown]
# ### `fillna`

# %% [markdown]
# The fillna() method allows us to replace empty cells with a value:

# %%
# Replace NULL values with the number 130:

import pandas as pd

df = pd.read_csv('data.csv')

df.fillna(130, inplace = True)

# %% [markdown]
# #### Replace Only For Specified Columns
#
# The example above replaces all empty cells in the whole Data Frame.
#
# To only replace empty values for one column, specify the column name for the DataFrame:

# %%
# Replace NULL values in the "Calories" columns with the number 130:

import pandas as pd

df = pd.read_csv('data.csv')

df.fillna({"Calories": 130}, inplace=True)

# %% [markdown]
# #### Replace Using Mean, Median, or Mode
#
# A common way to replace empty cells, is to calculate the mean, median or mode value of the column.
#
# Pandas uses the mean() median() and mode() methods to calculate the respective values for a specified column:

# %% [markdown]
# - Mean = the average value (the sum of all values divided by number of values).**bold text**

# %%
# Calculate the MEAN, and replace any empty values with it:

import pandas as pd

df = pd.read_csv('data.csv')

x = df["Calories"].mean()

df.fillna({"Calories": x}, inplace=True)

# %% [markdown]
# - Median = the value in the middle, after you have sorted all values ascending.

# %%
# Calculate the MEDIAN, and replace any empty values with it:

import pandas as pd

df = pd.read_csv('data.csv')

x = df["Calories"].median()

df.fillna({"Calories": x}, inplace=True)

# %% [markdown]
# Mode = the value that appears most frequently.

# %%
# Calculate the MODE, and replace any empty values with it:

import pandas as pd

df = pd.read_csv('data.csv')

#[0]: Since the .mode() method can return a pandas Series (in case of multiple modes or just to maintain consistency),
#  [0] is used to access the first mode value in the result.
x = df["Calories"].mode()[0]

df.fillna({"Calories": x}, inplace=True)

# %% [markdown]
# ### `isna()`
#
# The `isna()` method (which is an alias for `isnull()`) in Pandas is used to detect missing values (NaN, None, or NaT) in a DataFrame or Series. It returns a boolean DataFrame of the same shape, where `True` indicates a missing value and `False` indicates a non-missing value.

# %%
# Example using isna() with the existing df DataFrame

# Check for missing values in the entire DataFrame
print("Checking for missing values in the entire DataFrame:")
print(df.isna())

# Check for missing values in a specific column (e.g., 'Calories')
print("\nChecking for missing values in the 'Calories' column:")
print(df['Calories'].isna())

# Get the count of missing values in each column
print("\nCounting missing values in each column:")
print(df.isna().sum())

# Get the count of missing values in a specific column
print("\nCounting missing values in the 'Calories' column:")
print(df['Calories'].isna().sum())

# %% [markdown]
# ## Pandas - Cleaning Data of Wrong Format

# %% [markdown]
# Cells with data of wrong format can make it difficult, or even impossible, to analyze data.
#
# To fix it, you have two options: remove the rows, or convert all cells in the columns into the same format.

# %% [markdown]
# refer this- [link text](https://www.w3schools.com/python/pandas/pandas_cleaning_wrong_format.asp)

# %% [markdown]
# Let's try to convert all cells in the 'Date' column into dates.
#
# Pandas has a `to_datetime()` method for this:

# %%
# Convert to date:

import pandas as pd

df = pd.read_csv('data.csv')

df['Date'] = pd.to_datetime(df['Date'], format='mixed')

print(df.to_string())

# %% [markdown]
# `format='mixed':` This argument tells pandas to attempt to infer the format of the datetime strings in the 'Date' column automatically. This is useful when you have different date formats within the same column.

# %% [markdown]
# #### Removing Rows
#
# The result from the converting in the example above gave us a NaT value, which can be handled as a NULL value, and we can remove the row by using the dropna() method.

# %%
# Remove rows with a NULL value in the "Date" column:

df.dropna(subset=['Date'], inplace = True)

# %% [markdown]
# ## Pandas - Fixing Wrong Data

# %% [markdown]
# [link text](https://www.w3schools.com/python/pandas/pandas_cleaning_wrong_data.asp)

# %% [markdown]
# Wrong Data
# "Wrong data" does not have to be "empty cells" or "wrong format", it can just be wrong, like if someone registered "199" instead of "1.99".
#
# Sometimes you can spot wrong data by looking at the data set, because you have an expectation of what it should be.
#
# If you take a look at our data set, you can see that in row 7, the duration is 450, but for all the other rows the duration is between 30 and 60.
#
# It doesn't have to be wrong, but taking in consideration that this is the data set of someone's workout sessions, we conclude with the fact that this person did not work out in 450 minutes.

# %% [markdown]
# ### Replacing Values
# One way to fix wrong values is to replace them with something else.
#
# In our example, it is most likely a typo, and the value should be "45" instead of "450", and we could just insert "45" in row 7

# %%
# Set "Duration" = 45 in row 7:

df.loc[7, 'Duration'] = 45

# %% [markdown]
# For small data sets you might be able to replace the wrong data one by one, but not for big data sets.
#
# **To replace wrong data for larger data sets you can create some rules, e.g. set some boundaries for legal values, and replace any values that are outside of the boundaries**

# %% [markdown]
# Loop through all values in the "Duration" column.
#
# If the value is higher than 120, set it to 120:

# %%
for x in df.index:
  if df.loc(x, "Duration")>120:
    df.loc(x, "Duration") = 120

# %% [markdown]
# ### Removing Rows
#
# Another way of handling wrong data is to remove the rows that contains wrong data.
#
# This way you do not have to find out what to replace them with, and there is a good chance you do not need them to do your analyses.

# %%
for x in df.index:
  if df.loc(x, "Duration")> 120:
    df.drop(x, inplace=True)

# %% [markdown]
# ## Pandas - Removing Duplicates

# %% [markdown]
# To discover duplicates, we can use the `duplicated()` method.
#
# The `duplicated()` method returns a Boolean values for each row:

# %%
# Returns True for every row that is a duplicate, otherwise False:

print(df.duplicated())
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %% [markdown]
# ### Removing Duplicates
# To remove duplicates, use the `drop_duplicates()` method.

# %%
# Remove all duplicates:

df.drop_duplicates(inplace = True)

# %% [markdown]
# ## Pandas - Data Correlations

# %% [markdown]
# A great aspect of the Pandas module is the corr() method.
#
# The `corr()` method calculates the relationship between each column in your data set.
#
# The examples in this page uses a CSV file called: 'data.csv'.
#
# Download data.csv. or Open data.csv

# %%
# Show the relationship between the columns:

df.corr()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Note: The `corr()` method ignores "not numeric" columns.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Plotting
#
# Pandas uses the `plot()` method to create diagrams.
#
# We can use Pyplot, a submodule of the Matplotlib library to visualize the diagram on the screen.
#
# Read more about Matplotlib in our Matplotlib Tutorial.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# https://www.geeksforgeeks.org/python/python-oops-concepts/

# %% [markdown]
# https://pandas.pydata.org/docs/user_guide/merging.html

# %% [markdown]
# https://pandas.pydata.org/docs/getting_started/comparison/comparison_with_sql.html#compare-with-sql-join

# %% [markdown]
# https://www.w3schools.com/python/pandas/default.asp

# %%
https://www.w3schools.com/python/pandas/default.asp

# %%
t= ""
for j in range(5):
    t= t+"*"
    print(t)
    print("\n")
# Out:
# *
#
#
# **
#
#
# ***
#
#
# ****
#
#
# *****

# %%
for i in range(5):
  t= ""
  for j in range(i):
    t= t+"*"
    print(t)
  print("\n")
# Out:
# *
#
#
# *
# **
#
#
# *
# **
# ***
#
#
# *
# **
# ***
# ****
